# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
import csv
pp = PdfPages('multipage.pdf')
data = np.transpose(np.delete(np.genfromtxt('cib1data_FBLC.csv',delimiter=','),0,0))


for i in range(2):
#for i in range(len(lightdata[:,0])):
    model_I50 = data[0,:]
    
    #t = np.linspace(0,34800, num=6961)
    t = np.linspace(0,61200, num=12241)
    exp_t = t
    print(len(exp_t))
    
    exp_I50 = data[2,:]
    print(len(exp_I50))
    
      
    model_I100 =data[1,:]
    
    exp_I100 = data[3,:]

    
    plt.figure(1)
    plt.plot(exp_t,model_I50,label='model I=50',color='darkblue')
    plt.scatter(exp_t,exp_I50, c='lightsteelblue')
    
    plt.scatter(exp_t[240], exp_I50[240], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[480], exp_I50[480], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[720], exp_I50[720], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[960], exp_I50[960], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[1200], exp_I50[1200], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[1440], exp_I50[1440], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[1680], exp_I50[1680], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[1920], exp_I50[1920], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[2160], exp_I50[2160], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[2400], exp_I50[2400], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[2640], exp_I50[2640], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[2880], exp_I50[2880], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[3120], exp_I50[3120], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[3360], exp_I50[3360], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[3600], exp_I50[3600], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[3840], exp_I50[3840], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[4080], exp_I50[4080], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[4320], exp_I50[4320], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[4560], exp_I50[4560], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[4800], exp_I50[4800], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[5040], exp_I50[5040], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[5280], exp_I50[5280], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[5520], exp_I50[5520], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[5760], exp_I50[5760], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[6000], exp_I50[6000], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[6240], exp_I50[6240], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[6480], exp_I50[6480], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[6720], exp_I50[6720], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[6960], exp_I50[6960], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[7200], exp_I50[7200], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[7440], exp_I50[7440], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[7680], exp_I50[7680], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[7920], exp_I50[7920], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[8160], exp_I50[8160], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[8400], exp_I50[8400], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[8640], exp_I50[8640], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[8880], exp_I50[8880], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[9120], exp_I50[9120], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[9360], exp_I50[9360], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[9600], exp_I50[9600], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[9840], exp_I50[9840], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[10080], exp_I50[10080], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[10320], exp_I50[10320], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[10560], exp_I50[10560], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[10800], exp_I50[10800], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[11040], exp_I50[11040], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[11280], exp_I50[11280], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[11520], exp_I50[11520], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[11760], exp_I50[11760], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[12000], exp_I50[12000], c='royalblue', marker='o', s=10);
    plt.scatter(exp_t[12240], exp_I50[12240], c='royalblue', marker='o', s=10);

    #plt.legend()
    
   
    #plt.xlabel('Time [s]')
    #plt.ylabel('Fluorescence')
    #plt. suptitle('cib1 ',fontsize = 14)
    plt.ylim((0,0.5))
    plt.yticks([])
    plt.xticks([])
    #plt.xlim((0,3600))
    plt.savefig("VP16_50_3st1hillC.svg")
    plt.show()
    
    
    plt.figure(2)
    plt.plot(exp_t,model_I100, label='model I=100',color='darkgreen')
    plt.scatter(exp_t,exp_I100, c='lightgreen')
    plt.scatter(exp_t[240], exp_I100[240], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[480],  exp_I100[480], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[720],  exp_I100[720], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[960],  exp_I100[960], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[1200],  exp_I100[1200], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[1440],  exp_I100[1440], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[1680],  exp_I100[1680], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[1920],  exp_I100[1920], c='forestgreen', marker='D', s=10);
    plt.scatter(exp_t[2160],  exp_I100[2160], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[2400],  exp_I100[2400], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[2640],  exp_I100[2640], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[2880],  exp_I100[2880], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[3120],  exp_I100[3120], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[3360],  exp_I100[3360], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[3600],  exp_I100[3600], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[3840],  exp_I100[3840], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[4080],  exp_I100[4080], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[4320],  exp_I100[4320], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[4560],  exp_I100[4560], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[4800],  exp_I100[4800], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[5040],  exp_I100[5040], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[5280],  exp_I100[5280], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[5520],  exp_I100[5520], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[5760],  exp_I100[5760], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[6000],  exp_I100[6000], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[6240],  exp_I100[6240], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[6480],  exp_I100[6480], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[6720],  exp_I100[6720], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[6960],  exp_I100[6960], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[7200], exp_I100[7200], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[7440], exp_I100[7440], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[7680], exp_I100[7680], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[7920], exp_I100[7920], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[8160], exp_I100[8160], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[8400], exp_I100[8400], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[8640], exp_I100[8640], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[8880], exp_I100[8880], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[9120], exp_I100[9120], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[9360], exp_I100[9360], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[9600], exp_I100[9600], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[9840], exp_I100[9840], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[10080], exp_I100[10080], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[10320], exp_I100[10320], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[10560], exp_I100[10560], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[10800], exp_I100[10800], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[11040], exp_I100[11040], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[11280], exp_I100[11280], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[11520], exp_I100[11520], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[11760], exp_I100[11760], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[12000], exp_I100[12000], c='forestgreen', marker='o', s=10);
    plt.scatter(exp_t[12240], exp_I100[12240], c='forestgreen', marker='o', s=10);

    #plt.legend()
    
   
    #plt.xlabel('Time [s]')
    #plt.ylabel('Fluorescence')
    #plt. suptitle('cib1',fontsize = 14)
    plt.ylim((0,0.5))
    #plt.xlim((0,61200))
    plt.yticks([])
    plt.xticks([])
    plt.savefig("VP16_100_3st1hillC.svg")
    plt.show()
    
pp.close()

# %%
import csv
pp = PdfPages('multipage.pdf')
data = np.transpose(np.delete(np.genfromtxt('VP16data_3stFBLB.csv',delimiter=','),0,0))
print(data)

for i in range(2):
#for i in range(len(lightdata[:,0])):
    model_I50 = data[0,:]
    
    #t = np.linspace(0,34800, num=6961)
    t = np.linspace(0,61200, num=12241)
    exp_t = t
    print(len(exp_t))
    
    exp_I50 = data[2,:]
    print(len(exp_I50))
    
      
    model_I100 =data[1,:]
    
    exp_I100 = data[3,:]

    
    plt.figure
    plt.plot(exp_t,model_I50,label='model I=50',color='#FF9896', linestyle='dashed',linewidth=3)
    #plt.scatter(exp_t,exp_I50, c='lightsteelblue',s=50)
    
    plt.scatter(exp_t[240], exp_I50[240], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[480], exp_I50[480], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[720], exp_I50[720], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[960], exp_I50[960], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[1200], exp_I50[1200],edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[1440], exp_I50[1440], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[1680], exp_I50[1680], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[1920], exp_I50[1920], edgecolor='#FF9896', marker='o', facecolors='none',s=50);
    plt.scatter(exp_t[2160], exp_I50[2160],edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[2400], exp_I50[2400], edgecolor='#FF9896', marker='o', facecolors='none',s=50);
    plt.scatter(exp_t[2640], exp_I50[2640], edgecolor='#FF9896', marker='o', facecolors='none',s=50);
    plt.scatter(exp_t[2880], exp_I50[2880], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[3120], exp_I50[3120], edgecolor='#FF9896', marker='o', facecolors='none',s=50);
    plt.scatter(exp_t[3360], exp_I50[3360], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[3600], exp_I50[3600], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[3840], exp_I50[3840],edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[4080], exp_I50[4080], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[4320], exp_I50[4320], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[4560], exp_I50[4560], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[4800], exp_I50[4800], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[5040], exp_I50[5040], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[5280], exp_I50[5280], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[5520], exp_I50[5520], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[5760], exp_I50[5760], edgecolor='#FF9896', marker='o', facecolors='none',s=50);
    plt.scatter(exp_t[6000], exp_I50[6000], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[6240], exp_I50[6240],edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[6480], exp_I50[6480], edgecolor='#FF9896', marker='o', facecolors='none',s=50);
    plt.scatter(exp_t[6720], exp_I50[6720], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[6960], exp_I50[6960], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[7200], exp_I50[7200], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[7440], exp_I50[7440], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[7680], exp_I50[7680], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[7920], exp_I50[7920], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[8160], exp_I50[8160], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[8400], exp_I50[8400], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[8640], exp_I50[8640], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[8880], exp_I50[8880], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[9120], exp_I50[9120], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[9360], exp_I50[9360], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[9600], exp_I50[9600], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[9840], exp_I50[9840], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[10080], exp_I50[10080], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[10320], exp_I50[10320], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[10560], exp_I50[10560], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[10800], exp_I50[10800], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[11040], exp_I50[11040], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[11280], exp_I50[11280], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[11520], exp_I50[11520], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[11760], exp_I50[11760], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[12000], exp_I50[12000], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
    plt.scatter(exp_t[12240], exp_I50[12240], edgecolor='#FF9896', marker='o', facecolors='none', s=50);
   
    plt.plot(exp_t,model_I100, label='model I=100',color='#FF9896',linewidth=3)
    #plt.scatter(exp_t,exp_I100, c='lightgreen', s=50)
    plt.scatter(exp_t[240], exp_I100[240], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[480],  exp_I100[480], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[720],  exp_I100[720], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[960],  exp_I100[960], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[1200],  exp_I100[1200], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[1440],  exp_I100[1440], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[1680],  exp_I100[1680], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[1920],  exp_I100[1920], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[2160],  exp_I100[2160], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[2400],  exp_I100[2400], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[2640],  exp_I100[2640], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[2880],  exp_I100[2880], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[3120],  exp_I100[3120], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[3360],  exp_I100[3360], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[3600],  exp_I100[3600], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[3840],  exp_I100[3840], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[4080],  exp_I100[4080], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[4320],  exp_I100[4320], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[4560],  exp_I100[4560], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[4800],  exp_I100[4800], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[5040],  exp_I100[5040], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[5280],  exp_I100[5280], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[5520],  exp_I100[5520], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[5760],  exp_I100[5760], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6000],  exp_I100[6000], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6240],  exp_I100[6240], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6480],  exp_I100[6480], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6720],  exp_I100[6720], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6960],  exp_I100[6960], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[7200], exp_I100[7200],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[7440], exp_I100[7440],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[7680], exp_I100[7680],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[7920], exp_I100[7920],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[8160], exp_I100[8160],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[8400], exp_I100[8400],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[8640], exp_I100[8640],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[8880], exp_I100[8880],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[9120], exp_I100[9120], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[9360], exp_I100[9360],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[9600], exp_I100[9600],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[9840], exp_I100[9840],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[10080], exp_I100[10080],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[10320], exp_I100[10320],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[10560], exp_I100[10560],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[10800], exp_I100[10800],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[11040], exp_I100[11040],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[11280], exp_I100[11280], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[11520], exp_I100[11520],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[11760], exp_I100[11760],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[12000], exp_I100[12000],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[12240], exp_I100[12240],  c='#FF9896', marker='o', s=50);

    #plt.legend()
    
   
    #plt.xlabel('Time [s]')
    #plt.ylabel('Fluorescence')
    #plt. suptitle('VP16',fontsize = 14)
    plt.ylim((0,0.6))
    #plt.xlim((0,61200))
    #plt.yticks([])
    plt.xticks([])
    plt.savefig("VP16_BOTH_3stFBLB.svg")
    plt.show()
    
pp.close()

# %%
import csv
pp = PdfPages('multipage.pdf')
data = np.transpose(np.delete(np.genfromtxt('VP16_3stnohill_mCherry3raw.csv',delimiter=','),0,0))


for i in range(2):
#for i in range(len(lightdata[:,0])):
    model_I50 = data[1,:]
    
    #t = np.linspace(0,34800, num=6961)
    t = np.linspace(0,61200, num=12241)
    exp_t = t
    print(len(exp_t))
    
    exp_I50 = data[0,:]
    print(len(exp_I50))
    
    plt.figure(figsize=(7, 3))
    
    plt.plot(exp_t,model_I50, label='model I=100',color='#FF9896',linewidth=3)
    #plt.scatter(exp_t,exp_I50, c='lightgreen', s=50)
    plt.scatter(exp_t[240], exp_I50[240], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[480],  exp_I50[480], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[720],  exp_I50[720], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[960],  exp_I50[960], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[1200],  exp_I50[1200], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[1440],  exp_I50[1440], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[1680],  exp_I50[1680], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[1920],  exp_I50[1920], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[2160],  exp_I50[2160], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[2400],  exp_I50[2400], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[2640],  exp_I50[2640], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[2880],  exp_I50[2880], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[3120],  exp_I50[3120], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[3360],  exp_I50[3360], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[3600],  exp_I50[3600], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[3840],  exp_I50[3840], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[4080],  exp_I50[4080], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[4320],  exp_I50[4320], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[4560],  exp_I50[4560], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[4800],  exp_I50[4800], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[5040],  exp_I50[5040], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[5280],  exp_I50[5280], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[5520],  exp_I50[5520], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[5760],  exp_I50[5760], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6000],  exp_I50[6000], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6240],  exp_I50[6240], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6480],  exp_I50[6480], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6720],  exp_I50[6720], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[6960],  exp_I50[6960], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[7200], exp_I50[7200],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[7440], exp_I50[7440],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[7680], exp_I50[7680],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[7920], exp_I50[7920],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[8160], exp_I50[8160],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[8400], exp_I50[8400],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[8640], exp_I50[8640],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[8880], exp_I50[8880],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[9120], exp_I50[9120], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[9360], exp_I50[9360],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[9600], exp_I50[9600],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[9840], exp_I50[9840],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[10080], exp_I50[10080],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[10320], exp_I50[10320],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[10560], exp_I50[10560],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[10800], exp_I50[10800],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[11040], exp_I50[11040],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[11280], exp_I50[11280], c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[11520], exp_I50[11520],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[11760], exp_I50[11760],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[12000], exp_I50[12000],  c='#FF9896', marker='o', s=50);
    plt.scatter(exp_t[12240], exp_I50[12240],  c='#FF9896', marker='o', s=50);

    #plt.legend()
    
   
    #plt.xlabel('Time [s]')
    #plt.ylabel('Fluorescence')
    #plt. suptitle('med61',fontsize = 14)
    plt.ylim((0,0.6))
    #plt.xlim((0,61200))
    plt.yticks([])
    plt.xticks([])
    plt.savefig("VP16_3stnohill_both.svg")
    plt.show()
    
pp.close()
