# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
plt.figure(figsize=(6, 6))
btt1_50 = plt.scatter(0.162740241,0.114628418, edgecolor='#1F77B4', marker='o', facecolors='none', s=200)
btt1_100 = plt.scatter(0.195411814,0.158110748, c='#1F77B4', marker='o', s=200, label="btt1")
bur2_50 = plt.scatter(0.108248952,0.140109942,edgecolor='#AEC7E8', marker='*', facecolors='none', s=200)
bur2_100 = plt.scatter(0.129980911,0.086496688, c='#AEC7E8', marker='*', s=200, label="bur2")
caf4_50 = plt.scatter(0.092814542,0.087690331, edgecolor='#FF7F0E', marker='o', facecolors='none', s=200)
caf4_100 = plt.scatter(0.111447882,0.094115805, c='#FF7F0E', marker='>', s=200, label="caf4")
chz1_50 = plt.scatter(0.186100151,0.140633795, edgecolor='#2CA02C', marker='>', facecolors='none', s=200)
chz1_100 = plt.scatter(0.223461431,0.1885707, c='#2CA02C', marker='o', s=200, label="chz1")
cib1_50 = plt.scatter(0.131976535,0.122563305,edgecolor='#D62728', marker='o', facecolors='none', s=200)
cib1_100 = plt.scatter(0.158472021,0.140347787, c='#D62728', marker='o', s=200, label="cib1")
cpr1_50 = plt.scatter(0.274154775,0.242061606, edgecolor='#9467BD', marker='o', facecolors='none', s=200)
cpr1_100 = plt.scatter(0.329193763,0.353931338, c='#9467BD', marker='o', s=200, label="cpr1")
hir3_50 = plt.scatter(0.073915464,0.07282298, edgecolor='#8C564B', marker='*', facecolors='none', s=200)
hir3_100 = plt.scatter(0.088754649,0.064200278, c='#8C564B', marker='*', s=200, label="hir3")
hpa2_50 = plt.scatter(0.3291481,0.290301156, edgecolor='#E377C2', marker='o', facecolors='none', s=200)
hpa2_100 = plt.scatter(0.395227542,0.312048932, c='#E377C2', marker='o', s=200, label="hpa2")
ies1_50 = plt.scatter(0.034895791,0.031689445, edgecolor='#DBDB8D', marker='*', facecolors='none', s=200)
ies1_100 = plt.scatter(0.0419014387,0.017351525, c='#DBDB8D', marker='*', s=200, label="ies1")
med6_50 = plt.scatter(0.3073055660,0.298450933, edgecolor='#FFBB78', marker='o', facecolors='none', s=200)
med6_100 = plt.scatter(0.368999935,0.291016671, c='#FFBB78', marker='o', s=200, label="med6")
med8_50 = plt.scatter(0.290763485,0.28347822, edgecolor='#98DF8A', marker='>', facecolors='none' ,s=200)
med8_100 = plt.scatter(0.349136883,0.284955814, c='#98DF8A', marker='>', s=200, label="med8")
nut1_50 = plt.scatter(0.151319967,0.174158715, edgecolor='#BCBD22', marker='*', facecolors='none', s=200)
nut1_100 = plt.scatter(0.181698826,0.135060953, c='#BCBD22', marker='*', s=200, label="nut1")
rad6_50 = plt.scatter(0.150021841,0.101672749, edgecolor='#C49C94', marker='o', facecolors='none', s=200)
rad6_100 = plt.scatter(0.180140087,0.12783771, c='#C49C94', marker='o', s=200, label="rad6")
rtt102_50 = plt.scatter(0.177570095,0.15145949, edgecolor='#17BECF', marker='o', facecolors='none', s=200)
rtt102_100 = plt.scatter(0.21321887,0.176806911, c='#17BECF', marker='o', s=200, label="rtt102")
sus1_50 = plt.scatter(0.212387194,0.205029512, edgecolor='#C5B0D5', marker='*', facecolors='none', s=200)
sus1_100 = plt.scatter(0.255025848,0.179747628, c='#C5B0D5', marker='*', s=200, label="sus1")
VP16_50 = plt.scatter(0.316136588,0.438670397, edgecolor='#FF9896', marker='>', facecolors='none', s=200)
VP16_100 = plt.scatter(0.379603838,0.41344349, c='#FF9896', marker='>', s=200, label="VP16")

plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.3),
          ncol=8, fontsize=12)    
   
plt.xlabel('Model fluoresence (a.u.)')
plt.ylabel('Experimental fluoresence (a.u.)')
#plt. suptitle('cib1 ',fontsize = 14)
plt.ylim((0,0.5))
plt.xlim((0,0.5))
plt.savefig("endpoints_3st1hillA.svg",bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6, 6))
btt1_50 = plt.scatter(0.114628418
,616.667, edgecolor='#1F77B4', marker='o', facecolors='none', s=200)
btt1_100 = plt.scatter(0.158110748
,536.667, c='#1F77B4', marker='o', s=200, label="btt1")
bur2_50 = plt.scatter(0.140109942
,535,edgecolor='#AEC7E8', marker='*', facecolors='none', s=200)
bur2_100 = plt.scatter(0.086496688
,680, c='#AEC7E8', marker='*', s=200, label="bur2")
caf4_50 = plt.scatter(0.087690331
, 860, edgecolor='#FF7F0E', marker='o', facecolors='none', s=200)
caf4_100 = plt.scatter(0.094115805
,646.667, c='#FF7F0E', marker='o', s=200, label="caf4")
chz1_50 = plt.scatter(0.140633795
,568.889, edgecolor='#2CA02C', marker='o', facecolors='none', s=200)
chz1_100 = plt.scatter(0.1885707
,452, c='#2CA02C', marker='o', s=200, label="chz1")
cib1_50 = plt.scatter(0.122563305
,735.556,edgecolor='#D62728', marker='o', facecolors='none', s=200)
cib1_100 = plt.scatter(0.140347787
,535, c='#D62728', marker='o', s=200, label="cib1")
cpr1_50 = plt.scatter(0.242061606
,370, edgecolor='#9467BD', marker='o', facecolors='none', s=200)
cpr1_100 = plt.scatter(0.353931338
,316, c='#9467BD', marker='o', s=200, label="cpr1")
hir3_50 = plt.scatter(0.07282298
,740, edgecolor='#8C564B', marker='*', facecolors='none', s=200)
#hir3_100 = plt.scatter(1.1027,1000, c='#8C564B', marker='*', s=200, label="hir3")
hpa2_50 = plt.scatter(0.290301156
,350.968, edgecolor='#E377C2', marker='o', facecolors='none', s=200)
hpa2_100 = plt.scatter(0.312048932
,361.667, c='#E377C2', marker='o', s=200, label="hpa2")
#ies1_50 = plt.scatter(1.0853,1000, edgecolor='#DBDB8D', marker='*', facecolors='none', s=200)
#ies1_100 = plt.scatter(1.061,1000, c='#DBDB8D', marker='*', s=200, label="ies1")
med6_50 = plt.scatter(0.298450933
,357.5, edgecolor='#FFBB78', marker='>', facecolors='none', s=200)
med6_100 = plt.scatter(0.291016671
,381.25, c='#FFBB78', marker='>', s=200, label="med6")
med8_50 = plt.scatter(0.28347822
,407.273, edgecolor='#98DF8A', marker='>', facecolors='none' ,s=200)
med8_100 = plt.scatter(0.284955814
,389.565, c='#98DF8A', marker='>', s=200, label="med8")
nut1_50 = plt.scatter(0.174158715
,525.333, edgecolor='#BCBD22', marker='*', facecolors='none', s=200)
nut1_100 = plt.scatter(0.135060953
,605.714, c='#BCBD22', marker='*', s=200, label="nut1")
rad6_50 = plt.scatter(0.101672749
,626.667, edgecolor='#C49C94', marker='o', facecolors='none', s=200)
rad6_100 = plt.scatter(0.12783771
,597.778, c='#C49C94', marker='o', s=200, label="rad6")
rtt102_50 = plt.scatter(0.15145949
,504, edgecolor='#17BECF', marker='o', facecolors='none', s=200)
rtt102_100 = plt.scatter(0.176806911
,475, c='#17BECF', marker='o', s=200, label="rtt102")
sus1_50 = plt.scatter(0.205029512
, 461.818, edgecolor='#C5B0D5', marker='*', facecolors='none', s=200)
sus1_100 = plt.scatter(0.179747628
,503.478, c='#C5B0D5', marker='*', s=200, label="sus1")
VP16_50 = plt.scatter(0.438670397
,260, edgecolor='#FF9896', marker='*', facecolors='none', s=200)
VP16_100 = plt.scatter(0.41344349
,269.231, c='#FF9896', marker='*', s=200, label="VP16")

plt.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=12)    
   
plt.xlabel('Time dealy')
plt.ylabel('Experimental fluoresence @480(a.u.)')
#plt. suptitle('cib1 ',fontsize = 14)
#plt.ylim((0,0.5))
#plt.xlim((0,0.5))
plt.savefig("endpoints.svg",bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6, 6))
btt1_50 = plt.scatter(0.114628418
,616.667, edgecolor='#1F77B4', marker='o', facecolors='none', s=200)
btt1_100 = plt.scatter(0.158110748
,536.667, c='#1F77B4', marker='o', s=200, label="btt1")
bur2_50 = plt.scatter(0.140109942
,535,edgecolor='#AEC7E8', marker='*', facecolors='none', s=200)
bur2_100 = plt.scatter(0.086496688
,680, c='#AEC7E8', marker='*', s=200, label="bur2")
caf4_50 = plt.scatter(0.087690331
, 860, edgecolor='#FF7F0E', marker='o', facecolors='none', s=200)
caf4_100 = plt.scatter(0.094115805
,646.667, c='#FF7F0E', marker='o', s=200, label="caf4")
chz1_50 = plt.scatter(0.140633795
,568.889, edgecolor='#2CA02C', marker='o', facecolors='none', s=200)
chz1_100 = plt.scatter(0.1885707
,452, c='#2CA02C', marker='o', s=200, label="chz1")
cib1_50 = plt.scatter(0.122563305
,735.556,edgecolor='#D62728', marker='o', facecolors='none', s=200)
cib1_100 = plt.scatter(0.140347787
,535, c='#D62728', marker='o', s=200, label="cib1")
cpr1_50 = plt.scatter(0.242061606
,370, edgecolor='#9467BD', marker='o', facecolors='none', s=200)
cpr1_100 = plt.scatter(0.353931338
,316, c='#9467BD', marker='o', s=200, label="cpr1")
hir3_50 = plt.scatter(0.07282298
,740, edgecolor='#8C564B', marker='*', facecolors='none', s=200)
#hir3_100 = plt.scatter(1.1027,1000, c='#8C564B', marker='*', s=200, label="hir3")
hpa2_50 = plt.scatter(0.290301156
,350.968, edgecolor='#E377C2', marker='o', facecolors='none', s=200)
hpa2_100 = plt.scatter(0.312048932
,361.667, c='#E377C2', marker='o', s=200, label="hpa2")
#ies1_50 = plt.scatter(1.0853,1000, edgecolor='#DBDB8D', marker='*', facecolors='none', s=200)
#ies1_100 = plt.scatter(1.061,1000, c='#DBDB8D', marker='*', s=200, label="ies1")
med6_50 = plt.scatter(0.298450933
,357.5, edgecolor='#FFBB78', marker='>', facecolors='none', s=200)
med6_100 = plt.scatter(0.291016671
,381.25, c='#FFBB78', marker='>', s=200, label="med6")
med8_50 = plt.scatter(0.28347822
,407.273, edgecolor='#98DF8A', marker='>', facecolors='none' ,s=200)
med8_100 = plt.scatter(0.284955814
,389.565, c='#98DF8A', marker='>', s=200, label="med8")
nut1_50 = plt.scatter(0.174158715
,525.333, edgecolor='#BCBD22', marker='*', facecolors='none', s=200)
nut1_100 = plt.scatter(0.135060953
,605.714, c='#BCBD22', marker='*', s=200, label="nut1")
rad6_50 = plt.scatter(0.101672749
,626.667, edgecolor='#C49C94', marker='o', facecolors='none', s=200)
rad6_100 = plt.scatter(0.12783771
,597.778, c='#C49C94', marker='o', s=200, label="rad6")
rtt102_50 = plt.scatter(0.15145949
,504, edgecolor='#17BECF', marker='o', facecolors='none', s=200)
rtt102_100 = plt.scatter(0.176806911
,475, c='#17BECF', marker='o', s=200, label="rtt102")
sus1_50 = plt.scatter(0.205029512
, 461.818, edgecolor='#C5B0D5', marker='*', facecolors='none', s=200)
sus1_100 = plt.scatter(0.179747628
,503.478, c='#C5B0D5', marker='*', s=200, label="sus1")
VP16_50 = plt.scatter(0.438670397
,260, edgecolor='#FF9896', marker='*', facecolors='none', s=200)
VP16_100 = plt.scatter(0.41344349
,269.231, c='#FF9896', marker='*', s=200, label="VP16")

plt.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=12)    
   
plt.xlabel('Time dealy')
plt.ylabel('Experimental fluoresence @480(a.u.)')
#plt. suptitle('cib1 ',fontsize = 14)
#plt.ylim((0,0.5))
#plt.xlim((0,0.5))
plt.savefig("endpoints.svg",bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6, 6))
btt1_50 = plt.scatter(0.120902624,0.114628418, edgecolor='#1F77B4', marker='o', facecolors='none', s=200)
btt1_100 = plt.scatter(0.145174929,0.158110748, c='#1F77B4', marker='o', s=200, label="Btt1p")
bur2_50 = plt.scatter(0.106883387,0.140109942,edgecolor='#AEC7E8', marker='o', facecolors='none', s=200)
bur2_100 = plt.scatter(0.128341202,0.086496688, c='#AEC7E8', marker='o', s=200, label="Bur2p")
caf4_50 = plt.scatter(0.086420342,0.087690331, edgecolor='#FF7F0E', marker='o', facecolors='none', s=200)
caf4_100 = plt.scatter(0.103770011,0.094115805, c='#FF7F0E', marker='o', s=200, label="Caf4p")
chz1_50 = plt.scatter(0.148748982,0.140633795, edgecolor='#2CA02C', marker='o', facecolors='none', s=200)
chz1_100 = plt.scatter(0.178611686,0.1885707, c='#2CA02C', marker='o', s=200, label="Chz1p")
cib1_50 = plt.scatter(0.118607556,0.122563305,edgecolor='#D62728', marker='o', facecolors='none', s=200)
cib1_100 = plt.scatter(0.142419097,0.140347787, c='#D62728', marker='o', s=200, label="CIB1")
cpr1_50 = plt.scatter(0.310943394,0.242061606, edgecolor='#9467BD', marker='o', facecolors='none', s=200)
cpr1_100 = plt.scatter(0.373368102,0.353931338, c='#9467BD', marker='o', s=200, label="Cpr1p")
hir3_50 = plt.scatter(0.066024223,0.07282298, edgecolor='#8C564B', marker='o', facecolors='none', s=200)
hir3_100 = plt.scatter(0.079279179,0.064200278, c='#8C564B', marker='o', s=200, label="Hir3p")
hpa2_50 = plt.scatter(0.27134811,0.290301156, edgecolor='#E377C2', marker='o', facecolors='none', s=200)
hpa2_100 = plt.scatter(0.325823704,0.312048932, c='#E377C2', marker='o', s=200, label="Hpa2p")
ies1_50 = plt.scatter(0.020015497,0.031689445, edgecolor='#DBDB8D', marker='*', facecolors='none', s=200)
ies1_100 = plt.scatter(0.02403379,0.017351525, c='#DBDB8D', marker='o', s=200, label="Ies1p")
med6_50 = plt.scatter(0.27134811,0.298450933, edgecolor='#FFBB78', marker='o', facecolors='none', s=200)
med6_100 = plt.scatter(0.325823704,0.291016671, c='#FFBB78', marker='o', s=200, label="Med6p")
med8_50 = plt.scatter(0.244921879,0.28347822, edgecolor='#98DF8A', marker='o', facecolors='none' ,s=200)
med8_100 = plt.scatter(0.294092174,0.284955814, c='#98DF8A', marker='o', s=200, label="Med8p")
nut1_50 = plt.scatter(0.137110129,0.174158715, edgecolor='#BCBD22', marker='o', facecolors='none', s=200)
nut1_100 = plt.scatter(0.164636217,0.135060953, c='#BCBD22', marker='o', s=200, label="Nut1p")
rad6_50 = plt.scatter(0.101055311,0.101672749, edgecolor='#C49C94', marker='o', facecolors='none', s=200)
rad6_100 = plt.scatter(0.121343083,0.12783771, c='#C49C94', marker='o', s=200, label="Rad6p")
rtt102_50 = plt.scatter(0.145817278,0.15145949, edgecolor='#17BECF', marker='o', facecolors='none', s=200)
rtt102_100 = plt.scatter(0.175091416,0.176806911, c='#17BECF', marker='o', s=200, label="Rtt102p")
sus1_50 = plt.scatter(0.160856125,0.205029512, edgecolor='#C5B0D5', marker='o', facecolors='none', s=200)
sus1_100 = plt.scatter(0.193149443,0.179747628, c='#C5B0D5', marker='o', s=200, label="Sus1p")
VP16_50 = plt.scatter(0.408752066,0.438670397, edgecolor='#FF9896', marker='o', facecolors='none', s=200)
VP16_100 = plt.scatter(0.490812725,0.41344349, c='#FF9896', marker='o', s=200, label="VP16")

plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.3),
          ncol=8, fontsize=12)    
plt.xlabel('Model fluoresence (a.u.)')
plt.ylabel('Experimental fluoresence (a.u.)')
#plt. suptitle('cib1 ',fontsize = 14)
plt.ylim((0,0.5))
plt.xlim((0,0.5))
plt.savefig("endpoints legend.svg",bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6, 6))
data = np.transpose(np.delete(np.genfromtxt('3st1hillA_smaller_100_endpoints.csv',delimiter=','),0,0))
model_endpoints = data[1,:]
exp_endpoints = data[0,:]

plt.scatter(model_endpoints,exp_endpoints,c='k', marker='o', s=200)
labels = ['btt1','bur2','caf4','chz1','cib1','cpr1','hir3','hpa2','ies1','med6','med8','nut1','rad6','rtt102','sus1','VP16']
plt.xlabel('Model fluoresence (a.u.)')
plt.ylabel('Experimental fluoresence (a.u.)')
#plt. suptitle('cib1 ',fontsize = 14)
plt.ylim((0,0.5))
plt.xlim((0,0.5))
for i in range(len(labels)):
    plt.text(model_endpoints[i]+0.015, exp_endpoints[i]-0.02, labels[i])

#plt.savefig("endpoints_3st1hillA_smaller_50.svg")
plt.show()
